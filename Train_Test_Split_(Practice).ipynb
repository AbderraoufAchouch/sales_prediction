# %%
# import required libraries
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#import the data
df = pd.read_csv('/content/drive/MyDrive/datasets/Modified CA Housing-sklearn.csv')
df.head()
# Out:
#      MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0  832520.0      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1  830140.0      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2  725740.0      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3  564310.0      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4  384620.0      52.0  6.281853   1.081081       565.0  2.181467     37.85
#
#    Longitude  MedHouseVal
# 0    -122.23     452600.0
# 1    -122.22     358500.0
# 2    -122.24     352100.0
# 3    -122.25     341300.0
# 4    -122.25     342200.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   MedInc       20640 non-null  float64
#  1   HouseAge     20640 non-null  float64
#  2   AveRooms     20640 non-null  float64
#  3   AveBedrms    20640 non-null  float64
#  4   Population   20640 non-null  float64
#  5   AveOccup     20640 non-null  float64
#  6   Latitude     20640 non-null  float64
#  7   Longitude    20640 non-null  float64
#  8   MedHouseVal  20640 non-null  float64
# dtypes: float64(9)
# memory usage: 1.4 MB

# %%
X = df.drop(columns={"MedHouseVal"})
y = df["MedHouseVal"]
y
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: MedHouseVal, Length: 20640, dtype: float64

# %%
X_train,X_test, y_train,y_test =train_test_split(X,y,test_size=.2 , random_state=321)

# %%
X_train.head()
# Out:
#          MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  \
# 11840  202210.0      20.0  4.721875   1.025000       791.0  2.471875
# 15985  407930.0      52.0  4.949799   0.981928      1170.0  2.349398
# 2161   362500.0      37.0  5.865672   1.086567       796.0  2.376119
# 315    192500.0      45.0  4.198312   1.004219       630.0  2.658228
# 4735   575090.0      47.0  5.212219   1.009646       724.0  2.327974
#
#        Latitude  Longitude
# 11840     39.90    -120.93
# 15985     37.76    -122.47
# 2161      36.78    -119.81
# 315       37.76    -122.19
# 4735      34.05    -118.39

# %%
X_train.dtypes
# Out:
# MedInc        float64
# HouseAge      float64
# AveRooms      float64
# AveBedrms     float64
# Population    float64
# AveOccup      float64
# Latitude      float64
# Longitude     float64
# dtype: object

# %%
X_train.isna().sum()
# Out:
# MedInc        0
# HouseAge      0
# AveRooms      0
# AveBedrms     0
# Population    0
# AveOccup      0
# Latitude      0
# Longitude     0
# dtype: int64

# %%
X_train.shape
# Out:
# (16512, 8)

# %%
X_test.shape
# Out:
# (4128, 8)

# %% [markdown]
# Which X variable has more columns?

# %% [markdown]
# Both of them has the same number of columns  , because they represent the same set of features or characteristics that are used to make predictions

# %% [markdown]
# X_train has more rows because we are testing 80% of the data and the rest 20% is for the test
